# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/antalya-muratpaa-daire-kira-cretleri-2024-ocak/antalya_kiralik_ev.csv

# %% [markdown]
# # ***Antalya House Rent Analysis and Prediction***

# %% [markdown]
# # *ABOUT THE DATASET*
# 1. mahalle: The neighborhood where the apartment is located.
# 2. fiyat: Monthly rental price of the apartment (in Turkish Lira).
# 3. brut_alan_m2: Total gross area of the apartment (in square meters).
# 4. net_alan_m2: Total net area of the apartment (in square meters).
# 5. oda_sayisi: Total number of rooms in the apartment.
# 6. bina_yas: Age of the building (in years).
# 7. dairenin_bulundugu_kat: Floor number where the apartment is located
# 8. bina_kat_sayisi: Total number of floors in the building
# 9. isitma_turu: Type of heating system in the apartment
# 10. banyo_sayisi: Number of bathrooms  in the apartment.
# 11. balkon: Indicates whether the apartment has a balcony (Yes/No).
# 12. asansor: Indicates whether the building has an elevator (Yes/No).
# 13. otopark: Indicates whether the building has a parking area (Yes/No).
# 14. esya_durumu: Indicates whether the apartment is furnished or not (Furnished/Unfurnished).
# 15. site_icinde: Within a residential complex or not
# 16. aidat: Monthly maintenance fee for the apartment (in Turkish Lira).
# 17. depozito: Deposit amount for the apartment (in Turkish Lira).
# 18. sahibi: Indicates whether the apartment owner is an individual or a real estate agent.

# %% [markdown]
# # **Import Libraries**

# %%
import numpy as np #mureic python demek. çok boyutlu dizi, matris ile işlemler yapmamızı sağlar.
import pandas as pd #veri temzileme, dönüştürme, keşif için. seriler ve dataframeler sağlar.
import plotly.express as px #yüksek seviyeli bir veri görselleştirme kütüphanesidir. hızlı bir şekilde çeşitli grafikler oluşturmayı sağlar.
import matplotlib.pyplot as plt #statik, animasyonlu ve etkileşimli görselleştirmeler sağlar. pyplot da arayüz sağlar.
import seaborn as sns #plt üzerine kurulur ve grafik oluşturmayı kolaylaştırır.

# %%
import warnings #import edilir. uyarılarla etkileşim kurmak için yüklenir.
warnings.filterwarnings('ignore') #kod çalışırken oluşabilecek uyarıları gizler

# %% [markdown]
# # **Load and read the dataset**

# %% [markdown]
# We read the dataset with the help of
# "read.csv"

# %%
df=pd.read_csv("/kaggle/input/antalya-muratpaa-daire-kira-cretleri-2024-ocak/antalya_kiralik_ev.csv")

# %%
df.head()
# Out:
#    Unnamed: 0        mahalle    fiyat  brut_alan_m2  net_alan_m2 oda_sayisi  \
# 0           1   Bayındır Mh.  15000.0          90.0         80.0        2+1
# 1           2    Çaybaşı Mh.  29000.0         145.0        135.0        3+1
# 2           3   Güzeloba Mh.  24750.0         145.0        130.0        3+1
# 3           4  Şirinyalı Mh.  30000.0         230.0        200.0        3+1
# 4           5   Çağlayan Mh.  37500.0         320.0        300.0        4+2
#
#       bina_yas dairenin_bulundugu_kat  bina_kat_sayisi       isitma_turu  \
# 0  21-25 arası             Giriş Katı              4.0             Klima
# 1            0                      1              5.0  Kombi (Doğalgaz)
# 2  11-15 arası                      3              4.0             Klima
# 3   5-10 arası                      2              3.0   Doğalgaz Sobası
# 4  16-20 arası                      8              8.0             Klima
#
#    banyo_sayisi  balkon  asansor         otopark  esya_durumu  site_icinde  \
# 0           1.0       0        0    Açık Otopark            1            0
# 1           1.0       1        1  Kapalı Otopark            0            1
# 2           1.0       1        0    Açık Otopark            0            0
# 3           2.0       0        0    Açık Otopark            1            0
# 4           3.0       1        1    Açık Otopark            0            1
#
#    aidat  depozito  sahibi
# 0    100     15000       0
# 1   1500     30000       0
# 2    500     25000       1
# 3      0     30000       0
# 4      0     37500       0

# %% [markdown]
# # **Exploratory Data Analysis (EDA)**

# %% [markdown]
# Lets see if we have any null values

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              750 non-null    int64
#  1   mahalle                 750 non-null    object
#  2   fiyat                   750 non-null    float64
#  3   brut_alan_m2            750 non-null    float64
#  4   net_alan_m2             750 non-null    float64
#  5   oda_sayisi              750 non-null    object
#  6   bina_yas                750 non-null    object
#  7   dairenin_bulundugu_kat  750 non-null    object
#  8   bina_kat_sayisi         750 non-null    float64
#  9   isitma_turu             750 non-null    object
#  10  banyo_sayisi            750 non-null    float64
#  11  balkon                  750 non-null    int64
#  12  asansor                 750 non-null    int64
#  13  otopark                 750 non-null    object
#  14  esya_durumu             750 non-null    int64
#  15  site_icinde             750 non-null    int64
#  16  aidat                   750 non-null    int64
#  17  depozito                750 non-null    int64
#  18  sahibi                  750 non-null    int64
# dtypes: float64(5), int64(8), object(6)
# memory usage: 111.5+ KB

# %% [markdown]
# As we can see, we have a dataset with 750 rows and 19 columns.
# Using the info function, we were able to access basic information about the data. It shows the types of our variables and whether there are any missing values. As we can see, there are no missing values, but we will still examine the data in detail to confirm that.

# %% [markdown]
# Lets drop the "Unnamed: 0" column, cause we dont need any unnecessary datas.

# %%
df.drop("Unnamed: 0",axis=1,inplace=True)

# %% [markdown]
# **Do we have Absent Datas?
# **

# %%
df.isnull().sum()
# Out:
# mahalle                   0
# fiyat                     0
# brut_alan_m2              0
# net_alan_m2               0
# oda_sayisi                0
# bina_yas                  0
# dairenin_bulundugu_kat    0
# bina_kat_sayisi           0
# isitma_turu               0
# banyo_sayisi              0
# balkon                    0
# asansor                   0
# otopark                   0
# esya_durumu               0
# site_icinde               0
# aidat                     0
# depozito                  0
# sahibi                    0
# dtype: int64

# %% [markdown]
# having 0 as output for each column indicates that there are no missing (null) values in those columns. It means that all rows in those columns are filled.

# %%
df.describe().T
# Out:
#                  count          mean           std      min      25%      50%  \
# fiyat            750.0  24260.117333  16680.292541  10250.0  15000.0  20000.0
# brut_alan_m2     750.0    123.754667     53.263920     25.0     85.0    115.0
# net_alan_m2      750.0    111.505333     48.517233     20.0     75.0    100.0
# bina_kat_sayisi  750.0      5.204000      2.959853      1.0      3.0      4.0
# banyo_sayisi     750.0      1.280000      0.520860      1.0      1.0      1.0
# balkon           750.0      0.917333      0.275561      0.0      1.0      1.0
# asansor          750.0      0.626667      0.484012      0.0      0.0      1.0
# esya_durumu      750.0      0.482667      0.500033      0.0      0.0      0.0
# site_icinde      750.0      0.281333      0.449950      0.0      0.0      0.0
# aidat            750.0    419.381333   2644.590077      0.0      0.0     50.0
# depozito         750.0  21955.133333  24414.825180      0.0    500.0  18000.0
# sahibi           750.0      0.088000      0.283484      0.0      0.0      0.0
#
#                      75%       max
# fiyat            27000.0  200000.0
# brut_alan_m2       150.0     400.0
# net_alan_m2        140.0     370.0
# bina_kat_sayisi      7.0      17.0
# banyo_sayisi         1.0       4.0
# balkon               1.0       1.0
# asansor              1.0       1.0
# esya_durumu          1.0       1.0
# site_icinde          1.0       1.0
# aidat              300.0   70000.0
# depozito         27375.0  200000.0
# sahibi               0.0       1.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 750 entries, 0 to 749
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   mahalle                 750 non-null    object
#  1   fiyat                   750 non-null    float64
#  2   brut_alan_m2            750 non-null    float64
#  3   net_alan_m2             750 non-null    float64
#  4   oda_sayisi              750 non-null    object
#  5   bina_yas                750 non-null    object
#  6   dairenin_bulundugu_kat  750 non-null    object
#  7   bina_kat_sayisi         750 non-null    float64
#  8   isitma_turu             750 non-null    object
#  9   banyo_sayisi            750 non-null    float64
#  10  balkon                  750 non-null    int64
#  11  asansor                 750 non-null    int64
#  12  otopark                 750 non-null    object
#  13  esya_durumu             750 non-null    int64
#  14  site_icinde             750 non-null    int64
#  15  aidat                   750 non-null    int64
#  16  depozito                750 non-null    int64
#  17  sahibi                  750 non-null    int64
# dtypes: float64(5), int64(7), object(6)
# memory usage: 105.6+ KB

# %% [markdown]
# As we can see here, we have different data types in our dataset. So we need to define them before we can use them to train our model.

# %%
df.describe(include='object').T
# Out:
#                        count unique           top freq
# mahalle                  750     50  Güzeloba Mh.  163
# oda_sayisi               750     12           2+1  279
# bina_yas                 750     11    5-10 arası  159
# dairenin_bulundugu_kat   750     22             2  139
# isitma_turu              750     13         Klima  499
# otopark                  750      4  Açık Otopark  508

# %%
def colm(df):
    # Identify categorical columns (data type 'category', 'object', or 'bool')
    cat_cols = [col for col in df.columns if str(df[col].dtypes) in ['category','object','bool']]
    
    # Identify numerical columns with fewer than 10 unique values (considered categorical)
    num_but_cat = [col for col in df.columns if df[col].nunique() < 10 and df[col].dtypes in ['int','float']]
    
    # Identify categorical columns with more than 15 unique values (considered cardinal)
    cat_but_car = [col for col in df.columns if df[col].nunique() > 15 and str(df[col].dtypes) in ['category','object']]
    
    # Add numerical but categorical columns to the categorical columns list
    cat_cols = cat_cols + num_but_cat
    
    # Remove cardinal columns from the categorical columns list
    cat_cols = [col for col in cat_cols if col not in cat_but_car]
    
    # Identify numerical columns (data type 'int' or 'float')
    num_cols = [col for col in df.columns if df[col].dtypes in ['int', 'float']]
    
    # Remove columns that are already considered categorical from numerical columns
    num_cols = [col for col in num_cols if col not in cat_cols]

    # Print the lists of categorical, numerical, and cardinal columns
    print(f'Categorical : {cat_cols} \n Numerical : {num_cols} \n Cardinal : {cat_but_car}')
    
    # Return the lists of categorical, numerical, and cardinal columns
    return cat_cols, num_cols, cat_but_car

# %% [markdown]
# The colm function is used to create lists of categorical, numerical, and cardinal variables in a dataset. df is the dataframe provided as input to this function. The function examines this dataframe, categorizes the columns into three different categories, and processes them accordingly.

# %%
#Categorical Values: ['oda_sayisi', 'bina_yas', 'isitma_turu', 'otopark', 'banyo_sayisi', 'balkon', 'asansor', 'esya_durumu', 'site_icinde', 'sahibi'] 
 #Numerical Values : ['fiyat', 'brut_alan_m2', 'net_alan_m2', 'bina_kat_sayisi', 'aidat', 'depozito'] 
 #Cardinal Values : ['mahalle', 'dairenin_bulundugu_kat']

# %%
categorical, numerical, cardinal = colm(df)
# Out:
# Categorical : ['oda_sayisi', 'bina_yas', 'isitma_turu', 'otopark', 'banyo_sayisi', 'balkon', 'asansor', 'esya_durumu', 'site_icinde', 'sahibi']
#  Numerical : ['fiyat', 'brut_alan_m2', 'net_alan_m2', 'bina_kat_sayisi', 'aidat', 'depozito']
#  Cardinal : ['mahalle', 'dairenin_bulundugu_kat']

# %%
df['bina_yas'] = df['bina_yas'].replace({
    '0': 0,
    '1-5 arası': 3,
    '5-10 arası': 8,
    '11-15 arası': 13,
    '16-20 arası': 18,
    '21-25 arası': 23,
    '26-30 arası': 28,
    '31 ve üzeri': 35
}).astype(float)
df['bina_yas']
# Out:
# 0      23.0
# 1       0.0
# 2      13.0
# 3       8.0
# 4      18.0
#        ...
# 745    18.0
# 746    13.0
# 747    13.0
# 748     8.0
# 749    18.0
# Name: bina_yas, Length: 750, dtype: float64

# %% [markdown]
# Sometransformations enhance the dataset by adding new features that can help in further analysis, such as understanding pricing dynamics, space efficiency, and building characteristics.
#
# m2_basina_fiyat helps in understanding the cost efficiency of the space. By dividing the total price (fiyat) by the gross area (brut_alan_m2), you get the cost per square meter.
#
# net_brut_orani indicates how much of the gross area (brut_alan_m2) is actually usable (net_alan_m2). A higher ratio means better space efficiency.
#
# yas_kat_orani compares the age of the building (bina_yas) to the number of floors (bina_kat_sayisi). It can provide insights into the building's design and structural efficiency.

# %%
df['m2_basina_fiyat'] = df['fiyat'] / df['brut_alan_m2'] 
df['net_brut_orani'] = df['net_alan_m2'] / df['brut_alan_m2'] #Kullanılabilirlik
df['yas_kat_orani'] = df['bina_yas'] / df['bina_kat_sayisi'] # eğer korelasyon oranı çok düşük çıkarsa sonradan silinebilir

# %% [markdown]
# We have troubles with the 'mahalle' collumn. We need to compute the the average price, price per square meter, building age, and fee for each neighborhood, and then sorts the neighborhoods based on the average price in descending order. This will help us in comparing the overall price levels and other key features across different neighborhoods.

# %%
df.groupby('mahalle').agg({'fiyat':'mean','m2_basina_fiyat':'mean','bina_yas':'mean','aidat':'mean'}).sort_values(by='fiyat',ascending=False)
# Out:
#                          fiyat  m2_basina_fiyat   bina_yas        aidat
# mahalle
# Yeşilbahçe Mh.    37326.086957       224.281652  19.043478   745.652174
# Çağlayan Mh.      37024.615385       262.224514  13.030769   450.461538
# Şirinyalı Mh.     34634.146341       210.318731  18.000000   493.292683
# Fener Mah.        33488.095238       257.923824  15.309524  2296.428571
# Gençlik Mh.       33382.352941       209.107261  26.941176   289.117647
# Güzeloluk Mh.     32050.000000       240.757549  12.200000   510.000000
# Bahçelievler Mh.  31808.333333       191.476255  17.416667   225.000000
# Haşimişcan Mh.    29035.714286       294.372638  26.857143    42.857143
# Meltem Mah.       27312.500000       201.855089  21.750000   275.000000
# Ermenek Mah.      26762.500000       250.394345  12.500000     0.000000
# Meydankavağı Mh.  25790.000000       159.669953  14.240000   548.000000
# Muratpaşa Mh.        2
# Soğuksu Mh.          1
# Yüksekalan Mh.       1
# Varlık Mh.           1
# Kışla Mh.            1
# Sedir Mah.           1
# Memurevleri Mah.     1
# Mehmetçik Mh.        1
# Kızılsaray Mh.       1
# Haşimişcan Mh.       1
# Güzelbağ Mh.         1
# Gençlik Mh.          1
# Gebizli Mah.         1
# Şirinyalı Mh.        1
# Name: sahibi, dtype: int64

# %%
df.groupby(categorical).agg({'fiyat':'mean'}).sort_values(by='fiyat',ascending=False).reset_index()[0:15]
# Out:
#    oda_sayisi  bina_yas       isitma_turu                otopark  \
# 0         2+1       8.0             Klima           Açık Otopark
# 1         3+1       8.0  Kombi (Doğalgaz)         Kapalı Otopark
# 2         4+1      18.0  Kombi (Doğalgaz)           Açık Otopark
# 3         4+1      13.0  Kombi (Doğalgaz)  Açık & Kapalı Otopark
# 4         5+1      18.0  Kombi (Doğalgaz)  Açık & Kapalı Otopark
# 5         4+1      13.0     Yerden Isıtma         Kapalı Otopark
# 6         3+1      13.0  Kombi (Doğalgaz)         Kapalı Otopark
# 7         2+1      23.0             Klima           Açık Otopark
# 8         3+1      13.0           Merkezi         Kapalı Otopark
# 9         3+1      23.0  Kombi (Doğalgaz)  Açık & Kapalı Otopark
# 10        4+1      18.0  Kombi (Doğalgaz)  Açık & Kapalı Otopark
# 11        4+1      23.0           Merkezi           Açık Otopark
# 12        4+2      18.0  Kombi (Doğalgaz)           Açık Otopark
# 13        3+1      13.0  Kombi (Doğalgaz)  Açık & Kapalı Otopark
# 14        4+1      23.0             Klima  Açık & Kapalı Otopark
#
#     banyo_sayisi  balkon  asansor  esya_durumu  site_icinde  sahibi     fiyat
# 0            3.0       1        0            1            0       0  200000.0
# 1            2.0       1        1            1            1       0  200000.0
# 2            2.0       1        0            1            1       0  120000.0
# 3            3.0       1        1            0            1       1  107000.0
# 4            3.0       1        1            0            0       0  100000.0
# 5            2.0       1        1            0            0       0   90000.0
# 6            2.0       1        1            1            1       0   87500.0
# 7            1.0       1        1            1            0       0   85250.0
# 8            2.0       1        1            1            1       0   85000.0
# 9            1.0       1        1            1            1       0   80000.0
# 10           2.0       1        1            0            1       0   75000.0
# 11           3.0       1        1            1            1       0   72000.0
# 12           3.0       1        1            0            0       0   70000.0
# 13           2.0       1        1            0            1       0   70000.0
# 14           3.0       1        1            0            0       0   65000.0

# %% [markdown]
# We create data groups by a specified categorical column, calculates the average price for each category, sorts the results by average price in descending order, and then displays the top 15 categories with the highest average prices. This is useful for understanding which categories have the highest average property prices.

# %%
fig = px.histogram(df, x='fiyat', color_discrete_sequence=['#FF6347'])
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="4e843066-11b6-41d7-80dc-f5d9c2fbff98" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4e843066-11b6-41d7-80dc-f5d9c2fbff98")) {                    Plotly.newPlot(                        "4e843066-11b6-41d7-80dc-f5d9c2fbff98",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"fiyat=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#FF6347","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":
.0,16000.0,22000.0,30000.0,15500.0,30000.0,14000.0,15000.0,12000.0,23000.0,12000.0,16000.0,25000.0,13000.0,25000.0,26500.0,15000.0,23000.0,40000.0,22500.0,12500.0,50000.0,25000.0,26000.0,18000.0,11000.0,28000.0,18000.0,20000.0,28000.0,14000.0,14250.0,14500.0,35000.0,12500.0,23000.0,25250.0,17000.0,17800.0,15000.0,22500.0,20000.0,16000.0,25000.0,14000.0,85250.0,19500.0,55000.0,16000.0,21000.0,200000.0,25000.0,13000.0,12000.0,200000.0,22000.0,38000.0,40000.0,17000.0,75000.0,25000.0,16000.0,15000.0,21000.0,30000.0,33000.0,120000.0, ...

# %% [markdown]
# Now we have to define the upper limit for outliers by calculating the 99th percentile of the 'fiyat' column.
#
# In 'fiyat' dataset, some houses may have prices significantly higher than others. These excessively high prices can skew the analysis results or impair the model's performance. Therefore, by determining the upper limit below the 99th percentile of prices, we can identify these extreme values and decide how to address them.

# %%
outliers = df[['fiyat']].quantile(q=.99)
outliers
# Out:
# fiyat    88775.0
# Name: 0.99, dtype: float64

# %% [markdown]
# Let's filter the dataframe to include only rows where the 'fiyat' value is below the defined upper limit for outliers

# %%
df_non_outliers=df[df['fiyat']<outliers[0]]

# %%
px.histogram(df_non_outliers,x='fiyat', color_discrete_sequence=['#FF6347']) #fiyat'a bakalım
fig.show()
# Out:
# <div>                            <div id="fad394a3-1db4-442a-9103-535d29a95bbe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fad394a3-1db4-442a-9103-535d29a95bbe")) {                    Plotly.newPlot(                        "fad394a3-1db4-442a-9103-535d29a95bbe",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"fiyat=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#FF6347","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[15000.0,29000.0,24750.0,30000.0,37500.0,25000.0,13000.0,14000.0,25000.0,11500.0,24000.0,15800.0,11000.0,15000.0,12500.0,13000.0,15000.0,55000.0,17000.0,29000.0,18000.0,13500.0,40000.0,40000.0,25000.0,16000.0,45000.0,55000.0,15000.0,16500.0,25000.0,15000.0,19000.0,15000.0,20000.0,70000.0,18000.0,24000.0,23000.0,26000.0,30000.0,16000.0,30000.0,21000.0,21000.0,15000.0,18500.0,13500.0,21000.0,95000.0,24500.0,48000.0,35000.0,22000.0,15000.0,20000.0,20000.0,27000.0,15000.0,15000.0,25000.0,13000.0,42500.0,21500.0,13500.0,15000.0,25000.0,20000.0,19000.0,20000.0,80000.0,25000.0,15000.0,28000.0,13000.0,14000.0,75000.0,13000.0,15000.0,35000.0,16000.0,30000.0,18500.0,25000.0,17000.0,12500.0,47000.0,14000.0,25000.0,30000.0,14000.0,18000.0,13500.0,50000.0,31000.0,16000.0,13000.0,26000.0,28000.0,22000.0,13500.0,35000.0,13000.0,35000.0,15000.0,15750.0,25000.0,27000.0,50000.0,12000.0,32000.0,12500.0,25000.0,15000.0,21000.0,12000.0,22000.0,20000.0,12500.0,65000.0,15000.0,17000.0,26500.0,20000.0,20000.0,18000.0,18000.0,30000.0,20000.0,13500.0,16000.0,15000.0,30000.0,22000.0,12000.0,16000.0,18000.0,100000.0,26000.0,11000.0,12000.0,58000.0,17000.0,17500.0,50000.0,15250.0,30000.0,27000.0,15000.0,13000.
# Out:
#    oda_sayisi          isitma_turu                otopark  banyo_sayisi  \
# 0         3+1     Kombi (Doğalgaz)         Kapalı Otopark           2.0
# 1         3+1              Merkezi         Kapalı Otopark           2.0
# 2         3+1     Kombi (Doğalgaz)  Açık & Kapalı Otopark           1.0
# 3         4+1     Kombi (Doğalgaz)  Açık & Kapalı Otopark           2.0
# 4         4+1              Merkezi           Açık Otopark           3.0
# 5         4+2     Kombi (Doğalgaz)           Açık Otopark           3.0
# 6         3+1     Kombi (Doğalgaz)  Açık & Kapalı Otopark           2.0
# 7         4+1                Klima  Açık & Kapalı Otopark           3.0
# 8         3+1     Kombi (Doğalgaz)  Açık & Kapalı Otopark           3.0
# 9         2+1     Kombi (Doğalgaz)           Açık Otopark           2.0
# 10        2+1        Yerden Isıtma  Açık & Kapalı Otopark           2.0
# 11        4+1     Kombi (Doğalgaz)           Açık Otopark           2.0
# 12        3+1  Merkezi (Pay Ölçer)           Açık Otopark           1.0
# 13        4+1     Kombi (Doğalgaz)         Kapalı Otopark           2.0
# 14        2+1        Yerden Isıtma  Açık & Kapalı Otopark           2.0
#
#     balkon  asansor  esya_durumu  site_icinde  sahibi    fiyat
# 0        1        1            1            1       0  87500.0
# 1        1        1            1            1       0  85000.0
# 2        1        1            1            1       0  80000.0
# 3        1        1            0            1       0  75000.0
# 4        1        1            1            1       0  72000.0
# 5        1        1            0            0       0  70000.0
# 6        1        1            0            1       0  70000.0
# 7        1        1            0            0       0  65000.0
# 8        1        1            1            1       0  60000.0
# 9        1        1            1            1       0  60000.0
# 10       1        1            1            1       1  60000.0
# 11       1        1            0            0       0  55500.0
# 12       1        1            0            1       0  55000.0
# 13       1        1            0            1       0  55000.0
# 14       1        1            0            1       0  55000.0

# %%
df_non_outliers.groupby('mahalle').agg({'fiyat':'mean','m2_basina_fiyat':'mean','bina_yas':'mean','aidat':'mean'}).sort_values(by='fiyat',ascending=False)
# Out:
#                          fiyat  m2_basina_fiyat   bina_yas        aidat
# mahalle
# Yeşilbahçe Mh.    34704.545455       212.331751  19.318182   779.545455
# Şirinyalı Mh.     34634.146341       210.318731  18.000000   493.292683
# Güzeloluk Mh.     32050.000000       240.757549  12.200000   510.000000
# Bahçelievler Mh.  31808.333333       191.476255  17.416667   225.000000
# Fener Mah.        31695.121951       252.867883  15.365854  2291.463415
# Çağlayan Mh.      30751.612903       236.471937  13.112903   440.000000
# Gençlik Mh.       29843.750000       199.676465  27.812500   307.187500
# Haşimişcan Mh.    29035.714286       294.372638  26.857143    42.857143
# Meltem Mah.       27312.500000       201.855089  21.750000   275.000000
# Ermenek Mah.      26762.500000       250.394345  12.500000     0.000000
# Meydankavağı Mh.  25790.000000       159.669953  14.240000   548.000000
# Deniz Mah.        25354.166667       229.950694  15.250000   318.333333
# Kırcami Mh.       25000.000000        96.153846  13.000000     0.000000
# Güzeloba Mh.      23672.360248       258.294228  10.763975   506.552795
# Zerdalilik Mah.   21856.428571       180.124842  22.571429   121.428571
# Çaybaşı Mh.       21312.500000       209.086134  10.000000   325.000000
# Sedir Mah.          0.012000
# Çaybaşı Mh.         0.010667
# Güvenlik Mh.        0.010667
# Meltem Mah.         0.010667
# Haşimişcan Mh.      0.009333
# Zerdalilik Mah.     0.009333
# Dutlubahçe Mh.      0.008000
# Kızılsaray Mh.      0.008000
# Güzelbağ Mh.        0.008000
# Yeşildere Mh.       0.006667
# Güzeloluk Mh.       0.006667
# Cumhuriyet Mah.     0.006667
# Elmalı Mh.          0.006667
# Demircikara Mah.    0.005333
# Tahılpazarı Mh.     0.005333
# Yıldız Mh.          0.005333
# Doğuyaka Mh.        0.005333
# Ermenek Mah.        0.005333
# Memurevleri Mah.    0.005333
# Mehmetçik Mh.       0.002667
# Yenigöl Mh.         0.002667
# Balbey Mah.         0.001333
# Selçuk Mh.          0.001333
# Topçular Mh.        0.001333
# Kırcami Mh.         0.001333
# Yeşilova Mh.        0.001333
# Name: proportion, dtype: float64

# %%
df['fiyat'].plot.hist(bins=20)
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.describe(include="all").T
# Out:
#                         count unique           top freq          mean  \
# mahalle                   750     50  Güzeloba Mh.  163           NaN
# fiyat                   750.0    NaN           NaN  NaN  24260.117333
# brut_alan_m2            750.0    NaN           NaN  NaN    123.754667
# net_alan_m2             750.0    NaN           NaN  NaN    111.505333
# oda_sayisi                750     12           2+1  279           NaN
# bina_yas                750.0    NaN           NaN  NaN     14.493333
# dairenin_bulundugu_kat    750     22             2  139           NaN
# bina_kat_sayisi         750.0    NaN           NaN  NaN         5.204
# isitma_turu               750     13         Klima  499           NaN
# banyo_sayisi            750.0    NaN           NaN  NaN          1.28
# balkon                  750.0    NaN           NaN  NaN      0.917333
# asansor                 750.0    NaN           NaN  NaN      0.626667
# otopark                   750      4  Açık Otopark  508           NaN
# esya_durumu             750.0    NaN           NaN  NaN      0.482667
# site_icinde             750.0    NaN           NaN  NaN      0.281333
# aidat                   750.0    NaN           NaN  NaN    419.381333
# depozito                750.0    NaN           NaN  NaN  21955.133333
# sahibi                  750.0    NaN           NaN  NaN         0.088
# m2_basina_fiyat         750.0    NaN           NaN  NaN     207.45841
# net_brut_orani          750.0    NaN           NaN  NaN      0.897897
# yas_kat_orani           750.0    NaN           NaN  NaN      3.444169
#
#                                  std       min         25%         50%  \
# mahalle                          NaN       NaN         NaN         NaN
# fiyat                   16680.292541   10250.0     15000.0     20000.0
# brut_alan_m2                53.26392      25.0        85.0       115.0
# net_alan_m2                48.517233      20.0        75.0       100.0
# oda_sayisi                       NaN       NaN         NaN         NaN
# bina_yas                    8.734893       0.0         8.0        13.0
# dairenin_bulundugu_kat           NaN       NaN         NaN         NaN
# bina_kat_sayisi             2.959853       1.0         3.0         4.0
# isitma_turu                      NaN       NaN         NaN         NaN
# banyo_sayisi                 0.52086       1.0         1.0         1.0
# balkon                      0.275561       0.0         1.0         1.0
# asansor                     0.484012       0.0         0.0         1.0
# otopark                          NaN       NaN         NaN         NaN
# esya_durumu                 0.500033       0.0         0.0         0.0
# site_icinde                  0.44995       0.0         0.0         0.0
# aidat                    2644.590077       0.0         0.0        50.0
# depozito                 24414.82518       0.0       500.0     18000.0
# sahibi                      0.283484       0.0         0.0         0.0
# m2_basina_fiyat           103.564668      65.0  136.363636  181.818182
# net_brut_orani              0.049115  0.470588       0.875    0.909091
# yas_kat_orani               2.933788       0.0         1.6    2.666667
#
#                              75%          max
# mahalle                      NaN          NaN
# fiyat                    27000.0     200000.0
# brut_alan_m2               150.0        400.0
# net_alan_m2                140.0        370.0
# oda_sayisi                   NaN          NaN
# bina_yas                    23.0         35.0
# dairenin_bulundugu_kat       NaN          NaN
# bina_kat_sayisi              7.0         17.0
# isitma_turu                  NaN          NaN
# banyo_sayisi                 1.0          4.0
# balkon                       1.0          1.0
# asansor                      1.0          1.0
# otopark                      NaN          NaN
# esya_durumu                  1.0          1.0
# site_icinde                  1.0          1.0
# aidat                      300.0      70000.0
# depozito                 27375.0     200000.0
# sahibi                       0.0          1.0
# m2_basina_fiyat            250.0  1333.333333
# net_brut_orani          0.933333          1.0
# yas_kat_orani                4.5         28.0

# %%
numeric_columns=df.select_dtypes(include=['number'])
numeric_columns
# Out:
#        fiyat  brut_alan_m2  net_alan_m2  bina_yas  bina_kat_sayisi  \
# 0    15000.0          90.0         80.0      23.0              4.0
# 1    29000.0         145.0        135.0       0.0              5.0
# 2    24750.0         145.0        130.0      13.0              4.0
# 3    30000.0         230.0        200.0       8.0              3.0
# 4    37500.0         320.0        300.0      18.0              8.0
# ..       ...           ...          ...       ...              ...
# 745  16000.0         120.0        110.0      18.0              3.0
# 746  25000.0         170.0        160.0      13.0             17.0
# 747  30000.0         220.0        200.0      13.0             13.0
# 748  20000.0          70.0         65.0       8.0              5.0
# 749  17500.0         100.0         80.0      18.0              4.0
#
#      banyo_sayisi  balkon  asansor  esya_durumu  site_icinde  aidat  depozito  \
# 0             1.0       0        0            1            0    100     15000
# 1             1.0       1        1            0            1   1500     30000
# 2             1.0       1        0            0            0    500     25000
# 3             2.0       0        0            1            0      0     30000
# 4             3.0       1        1            0            1      0     37500
# ..            ...     ...      ...          ...          ...    ...       ...
# 745           1.0       1        1            0            0    250     16000
# 746           1.0       1        1            1            0      0     25000
# 747           2.0       1        1            0            0      0     30000
# 748           1.0       1        1            1            0    500     20000
# 749           2.0       1        0            1            0    300     25000
#
#      sahibi  m2_basina_fiyat  net_brut_orani  yas_kat_orani
# 0         0       166.666667        0.888889       5.750000
# 1         0       200.000000        0.931034       0.000000
# 2         1       170.689655        0.896552       3.250000
# 3         0       130.434783        0.869565       2.666667
# 4         0       117.187500        0.937500       2.250000
# ..      ...              ...             ...            ...
# 745       0       133.333333        0.916667       6.000000
# 746       0       147.058824        0.941176       0.764706
# 747       0       136.363636        0.909091       1.000000
# 748       1       285.714286        0.928571       1.600000
# 749       0       175.000000        0.800000       4.500000
#
# [750 rows x 16 columns]

# %%
numeric_columns.corr()
# Out:
#                     fiyat  brut_alan_m2  net_alan_m2  bina_yas  \
# fiyat            1.000000      0.511984     0.495797 -0.033311
# brut_alan_m2     0.511984      1.000000     0.991472  0.259730
# net_alan_m2      0.495797      0.991472     1.000000  0.264372
# bina_yas        -0.033311      0.259730     0.264372  1.000000
# bina_yas               -0.309841        0.092332       0.625898
# bina_kat_sayisi        -0.005219        0.121714      -0.395540
# banyo_sayisi            0.104620        0.024100      -0.146647
# balkon                 -0.155017        0.137510       0.030040
# asansor                 0.065347        0.069109      -0.485050
# esya_durumu             0.379666       -0.102443      -0.100155
# site_icinde             0.235941        0.030794      -0.157101
# aidat                   0.105580        0.003063      -0.043761
# depozito                0.235368       -0.017329      -0.098676
# sahibi                  0.020010       -0.022990      -0.009327
# m2_basina_fiyat         1.000000       -0.125527      -0.189545
# net_brut_orani         -0.125527        1.000000      -0.030646
# yas_kat_orani          -0.189545       -0.030646       1.000000

# %%
df['fiyat'].median()
# Out:
# 20000.0

# %%
df.plot.scatter(x='brut_alan_m2', y='fiyat', alpha=0.5, color='green')
plt.title('Brüt Alan vs Fiyat')
plt.show()

# %%
missing_percentage = df.isnull().mean() * 100
missing_percentage
# Out:
# mahalle                   0.0
# fiyat                     0.0
# brut_alan_m2              0.0
# net_alan_m2               0.0
# oda_sayisi                0.0
# bina_yas                  0.0
# dairenin_bulundugu_kat    0.0
# bina_kat_sayisi           0.0
# isitma_turu               0.0
# banyo_sayisi              0.0
# balkon                    0.0
# asansor                   0.0
# otopark                   0.0
# esya_durumu               0.0
# site_icinde               0.0
# aidat                     0.0
# depozito                  0.0
# sahibi                    0.0
# m2_basina_fiyat           0.0
# net_brut_orani            0.0
# yas_kat_orani             0.0
# dtype: float64

# %%
pivot_table = df.pivot_table(values='fiyat', index='mahalle', columns='isitma_turu', aggfunc='mean')
pivot_table
# Out:
# isitma_turu       Doğalgaz Sobası  Fancoil Ünitesi  Güneş Enerjisi  \
# mahalle
# Altındağ Mh.                  NaN              NaN             NaN
# Bahçelievler Mh.              NaN              NaN             NaN
# Balbey Mah.                   NaN              NaN             NaN
# Bayındır Mh.                  NaN              NaN             NaN
# Cumhuriyet Mah.               NaN              NaN             NaN
# Demircikara Mah.              NaN              NaN             NaN
# Deniz Mah.                    NaN              NaN             NaN
# Doğuyaka Mh.                  NaN              NaN             NaN
# Dutlubahçe Mh.                NaN              NaN             NaN
# Elmalı Mh.                    NaN              NaN             NaN
# Ermenek Mah.                  NaN              NaN             NaN
# Etiler Mah.                   NaN              NaN             NaN
# Fener Mah.                    NaN              NaN             NaN
# Gebizli Mah.                  NaN              NaN             NaN
# Gençlik Mh.                   NaN              NaN             NaN
# Güvenlik Mh.                  NaN              NaN             NaN
# Güzelbağ Mh.                  NaN              NaN         13000.0
# Güzeloba Mh.                  NaN              NaN             NaN
# Güzeloluk Mh.                 NaN              NaN             NaN
# Haşimişcan Mh.                NaN              NaN             NaN
# Konuksever Mah.               NaN              NaN             NaN
# Kırcami Mh.                   NaN              NaN             NaN
# Kızılarık Mh.                 NaN              NaN             NaN
# Kızılsaray Mh.                NaN              NaN             NaN
# Kızıltoprak Mh.               NaN              NaN             NaN
# Kışla Mh.                     NaN              NaN             NaN
# Mehmetçik Mh.                 NaN              NaN             NaN
# Meltem Mah.                   NaN              NaN             NaN
# Memurevleri Mah.              NaN              NaN             NaN
# Meydankavağı Mh.              NaN              NaN             NaN
# Zerdalilik Mah.             NaN  18000.000000      NaN
# Çaybaşı Mh.                 NaN  17000.000000      NaN
# Çağlayan Mh.            55000.0  13000.000000      NaN
# Üçgen Mh.                   NaN  17500.000000      NaN
# Şirinyalı Mh.               NaN  27333.333333      NaN

# %%
vc=df_non_outliers['mahalle'].value_counts()
other = vc[vc<=10]
df_non_outliers['mahalle'] = df_non_outliers['mahalle'].apply(lambda x: 'other' if x in other else x)

# %%
df_non_outliers['dairenin_bulundugu_kat'] = df_non_outliers['dairenin_bulundugu_kat'].apply(lambda x:0 if (x=='Giriş Katı' or x=='Bahçe Katı' or x=='Yüksek Giriş' or x=='Zemin Kat') else(-1 if (x=='Bodrum Kat' or x=='Giriş Altı Kot 2') else(-5 if (x=='Çatı Katı' or x=='Villa Tipi') else x))).astype('int')

# %%
df_non_outliers['dairenin_bulundugu_kat'].value_counts(), df_non_outliers['mahalle'].value_counts()
# Out:
# (dairenin_bulundugu_kat
#   0     152
#   1     137
#   2     137
#   3     100
#   4      76
#   6      36
#   5      33
#   9      12
#   7      12
#   8      11
#  -5       9
#   11      6
#   12      5
#   10      5
#  -1       4
#   15      4
#   13      3
#  Name: count, dtype: int64,
#  mahalle
#  Güzeloba Mh.        161
#  other               128
#  Çağlayan Mh.         62
#  Şirinyalı Mh.        41
#  Fener Mah.           41
#  Kızılarık Mh.        35
#  Meydankavağı Mh.     25
#  Bayındır Mh.         22
#  Yeşilbahçe Mh.       22
#  Yüksekalan Mh.       17
#  Konuksever Mah.      17
#  Gebizli Mah.         17
#  Gençlik Mh.          16
#  Yenigün Mh.          15
#  Muratpaşa Mh.        14
#  Kışla Mh.            13
#  Kızıltoprak Mh.      13
#  Varlık Mh.           13
#  Bahçelievler Mh.     12
#  Üçgen Mh.            12
#  Deniz Mah.           12
#  Soğuksu Mh.          12
#  Altındağ Mh.         11
#  Sinan Mah.           11
#  Name: count, dtype: int64)

# %%
dummie_df = pd.get_dummies(df_non_outliers[categorical_no],drop_first=True)

# %%
df_non_outliers.drop(categorical_no,axis=1,inplace=True)
df_non_outliers = pd.concat([df_non_outliers,dummie_df],axis=1)

# %%
from sklearn.preprocessing import LabelEncoder
ss = LabelEncoder()
df_non_outliers['mahalle'] = ss.fit_transform(df_non_outliers['mahalle'])
df_non_outliers['dairenin_bulundugu_kat'] = ss.fit_transform(df_non_outliers['dairenin_bulundugu_kat'])

# %%
df_non_outliers.corr()['fiyat'].sort_values(ascending=False,key=abs)[1:]
# Out:
# brut_alan_m2                       0.539966
# net_alan_m2                        0.527839
# banyo_sayisi                       0.501710
# depozito                           0.499828
# m2_basina_fiyat                    0.493237
# dairenin_bulundugu_kat             0.400515
# bina_kat_sayisi                    0.369649
# isitma_turu_Kombi (Doğalgaz)       0.365577
# site_icinde                        0.306488
# isitma_turu_Klima                 -0.298436
# oda_sayisi_4+1                     0.276200
# asansor                            0.259836
# aidat                              0.235855
# otopark_Kapalı Otopark             0.223273
# oda_sayisi_3+1                     0.203340
# yas_kat_orani                     -0.181738
# isitma_turu_Merkezi                0.175740
# otopark_Yok                       -0.172502
# esya_durumu                        0.150321
# isitma_turu_Yerden Isıtma          0.147808
# isitma_turu_Yok                   -0.140466
# balkon                             0.140200
# oda_sayisi_2+1                    -0.129594
# oda_sayisi_4+2                     0.118631
# isitma_turu_Merkezi (Pay Ölçer)    0.090287
# otopark_Açık Otopark              -0.085308
# oda_sayisi_2+0                    -0.073375
# oda_sayisi_Stüdyo (1+0)           -0.063056
# net_brut_orani                     0.058180
# oda_sayisi_3.5+1                   0.058149
# isitma_turu_Kat Kaloriferi         0.054775
# isitma_turu_Soba                  -0.050585
# mahalle                            0.049456
# isitma_turu_Güneş Enerjisi        -0.039821
# oda_sayisi_5+1                     0.038692
# oda_sayisi_6+1                     0.032387
# oda_sayisi_5+2                     0.029957
# isitma_turu_Fancoil Ünitesi       -0.028139
# bina_yas                          -0.025210
# isitma_turu_Şömine                -0.025057
# oda_sayisi_2.5+1                  -0.015812
# sahibi                            -0.007520
# isitma_turu_Kombi (Elektrik)      -0.007112
# Name: fiyat, dtype: float64

# %%
from sklearn.model_selection import train_test_split

X = df_non_outliers.drop('fiyat',axis=1)
y = df_non_outliers['fiyat']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.2,random_state=43)

# %%
#modelleme ve en uygun modeli bulalım
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVR
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor

def compare_models(X_train,X_test,y_train, y_test):
    models = [
        LinearRegression(),
        Ridge(),
        Lasso(),
        DecisionTreeRegressor(),
        RandomForestRegressor(),
        SVR(),
        XGBRegressor(),
        LGBMRegressor(verbose=-1),
        CatBoostRegressor(verbose=False)
    ]
    
    results = []
    for model in models:
        model_name = model.__class__.__name__

        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        rmse = mean_squared_error(y_test, y_pred, squared=False)

        r2 = r2_score(y_test, y_pred)
        scores = cross_val_score(model, X_train, y_train, cv=5, scoring='neg_mean_squared_error')
        rmse_cv = np.sqrt(-scores.mean())
        print(f"{model_name} = RMSE: {rmse}, RMSEcv : {rmse_cv}, r2 Score: {r2}")

# %%
compare_models(X_train,X_test,y_train, y_test)
# Out:
# LinearRegression = RMSE: 3378.361749145278, RMSEcv : 4696.474540301507, r2 Score: 0.896470268652034
# Ridge = RMSE: 3269.60134409069, RMSEcv : 4600.188126497544, r2 Score: 0.9030288845997794
# Lasso = RMSE: 3326.3661640207465, RMSEcv : 4669.467540473477, r2 Score: 0.899632549317424
# DecisionTreeRegressor = RMSE: 4359.333907157601, RMSEcv : 5093.618674316406, r2 Score: 0.8276175473505819
# RandomForestRegressor = RMSE: 3065.173752420054, RMSEcv : 3764.1756570513717, r2 Score: 0.9147757907119832
# SVR = RMSE: 11055.252034934027, RMSEcv : 12609.12480264714, r2 Score: -0.1086388169040926
# XGBRegressor = RMSE: 2550.6389999927014, RMSEcv : 3435.6969375214735, r2 Score: 0.940986581037318
# LGBMRegressor = RMSE: 2722.16495115958, RMSEcv : 3589.9110954399175, r2 Score: 0.9327826076108943
# CatBoostRegressor = RMSE: 1886.4630208386616, RMSEcv : 2950.893791388626, r2 Score: 0.967718821786263

# %%
model = CatBoostRegressor(verbose=False)
model.fit(X_train, y_train,verbose=False)
y_pred = model.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
r2Score = r2_score(y_test, y_pred)
print(f" RMSE: {rmse} \n  r2: {r2Score}")
# Out:
#  RMSE: 1886.4630208386616
#   r2: 0.967718821786263
